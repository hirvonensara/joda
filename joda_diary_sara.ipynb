# %% [markdown]
# # Johdanto datatieteeseen -oppimispäiväkirja - Sara Hirvonen
# ## 1. viikko
# Kerro osallistuitko viikon opetukseen ja kuvaa päiväkirjan laatimisessa käyttämäsi aineisto:
# Osallistuin viikon luennoille osallistumalla aloitusluennolle ja katsomalla koodiklinikan (jälkikäteen).
#
# Tiivistä jokaisen luentoviikon keskeiset asiat tekstiksi:

# %%
from IPython.core.display import HTML

# %% [markdown]
# ### Viisi oivallusta / tärkeintä oppimaani asiaa:

# %% [markdown]
# 1. eka
# 2. toka
# 3. kolmas
# 4. neljäs
# 5. viides

# %% [markdown]
# ### Kolme kehityskohdetta / flippausvinkkiä:
# 1. ekaa
# 2. toka
# 3. kolmas

# %% [markdown]
# ### Kymmenen koodirivin demo
